# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib

# %%
data=np.random.rand(50)
print(data)
print(type(data))
# Out:
# [0.125159   0.42928835 0.35547624 0.66101693 0.32641034 0.0425166
#  0.41779685 0.90978899 0.64798521 0.34115959 0.18679693 0.93087038
#  0.42415943 0.62823712 0.08842269 0.64497443 0.69713948 0.47031997
#  0.09630972 0.9437061  0.17423364 0.98837498 0.58294827 0.41116659
#  0.83879332 0.95698797 0.25668452 0.17361831 0.98149836 0.90441426
#  0.59867745 0.04442171 0.5897531  0.71922796 0.20133687 0.4664862
#  0.77926852 0.94447205 0.67227841 0.83505263 0.69274726 0.1789892
#  0.64131339 0.07766593 0.45411525 0.63377966 0.72011869 0.52167664
#  0.58911395 0.72260161]
# <class 'numpy.ndarray'>

# %%
seri=pd.Series(data)
print(seri)
print(type(seri))
# Out:
# 0     0.125159
# 1     0.429288
# 2     0.355476
# 3     0.661017
# 4     0.326410
# 5     0.042517
# 6     0.417797
# 7     0.909789
# 8     0.647985
# 9     0.341160
# 10    0.186797
# 11    0.930870
# 12    0.424159
# 13    0.628237
# 14    0.088423
# 15    0.644974
# 16    0.697139
# 17    0.470320
# 18    0.096310
# 19    0.943706
# 20    0.174234
# 21    0.988375
# 22    0.582948
# 23    0.411167
# 24    0.838793
# 25    0.956988
# 26    0.256685
# 27    0.173618
# 28    0.981498
# 29    0.904414
# 30    0.598677
# 31    0.044422
# 32    0.589753
# 33    0.719228
# 34    0.201337
# 35    0.466486
# 36    0.779269
# 37    0.944472
# 38    0.672278
# 39    0.835053
# 40    0.692747
# 41    0.178989
# 42    0.641313
# 43    0.077666
# 44    0.454115
# 45    0.633780
# 46    0.720119
# 47    0.521677
# 48    0.589114
# 49    0.722602
# dtype: float64
# <class 'pandas.core.series.Series'>

# %%
seri.plot()

# %%
mapplot.style.use("ggplot")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-9292e0e44d94> in <module>
# ----> 1 mapplot.style.use("ggplot")
#
# NameError: name 'mapplot' is not defined

# %%
matplotlib.style.use("ggplot")
seri.plot()

# %%
df=pd.DataFrame(data_set,columns=['A','B','C'])
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-5f385db5612b> in <module>
# ----> 1 df=pd.DataFrame(data_set,columns=['A','B','C'])
#       2 df
#
# NameError: name 'data_set' is not defined
